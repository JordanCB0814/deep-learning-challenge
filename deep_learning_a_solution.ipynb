# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
import pandas as pd
import tensorflow as tf
import numpy as np

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
counts_df = application_df.drop(columns=['EIN', 'NAME'])
counts_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
counts_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
counts_df = counts_df["APPLICATION_TYPE"].value_counts()
counts_df
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = list(counts_df[counts_df<500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
#  YOUR CODE GOES HERE
class_counts = application_df["CLASSIFICATION"].value_counts()
class_counts
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1248        1
# C6100        1
# C1820        1
# C1900        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
class_counts[class_counts>1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C2300       32
# C7200       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1600        5
# C1257        5
# C2710        3
# C0           3
# C1260        3
# C1256        2
# C1234        2
# C1267        2
# C1246        2
# C3200        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = list(class_counts[class_counts<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
dummies_df = pd.get_dummies(application_df)
dummies_df.head()
# Out:
#         EIN  STATUS  ASK_AMT  IS_SUCCESSFUL  \
# 0  10520599       1     5000              1
# 1  10531628       1   108590              1
# 2  10547893       1     5000              0
# 3  10553066       1     6692              1
# 4  10556103       1   142590              1
#
#    NAME_1 DAY RANCH RESCUE AND RURAL OKLAHOMA ANIMAL RESOURCE INC  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    NAME_100 BLACK MEN OF AMERICA  NAME_100 BLACK MEN OF MEMPHIS INC  \
# 0                          False                              False
# 1                          False                              False
# 2                          False                              False
# 3                          False                              False
# 4                          False                              False
#
#    NAME_100 BLACK MEN OF WEST GEORGIA INC  NAME_1150 WEBSTER STREET INC  \
# 0                                   False                         False
# 1                                   False                         False
# 2                                   False                         False
# 3                                   False                         False
# 4                                   False                         False
#
#    NAME_116TH CAVALRY REGIMENT CHAPTER OF THE US CAVALRY & ARMOR ASSOCIATION  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    ...  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0  ...              False                   False                     False
# 1  ...               True                   False                     False
# 2  ...              False                   False                     False
# 3  ...              False                    True                     False
# 4  ...              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 19613 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = dummies_df["IS_SUCCESSFUL"]
X = dummies_df.drop(columns="IS_SUCCESSFUL")

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=47)

# %%
# Check if it's a DataFrame and for NaN values
print(X_train.shape, X_test.shape)
print(X_train.info())
print(np.isnan(X_train).sum())
# Out:
# (25724, 19612) (8575, 19612)
# <class 'pandas.core.frame.DataFrame'>
# Index: 25724 entries, 10073 to 11528
# Columns: 19612 entries, EIN to SPECIAL_CONSIDERATIONS_Y
# dtypes: bool(19609), int64(3)
# memory usage: 481.8 MB
# None
# EIN                                                               0
# STATUS                                                            0
# ASK_AMT                                                           0
# NAME_1 DAY RANCH RESCUE AND RURAL OKLAHOMA ANIMAL RESOURCE INC    0
# NAME_100 BLACK MEN OF AMERICA                                     0
#                                                                  ..
# INCOME_AMT_25000-99999                                            0
# INCOME_AMT_50M+                                                   0
# INCOME_AMT_5M-10M                                                 0
# SPECIAL_CONSIDERATIONS_N                                          0
# SPECIAL_CONSIDERATIONS_Y                                          0
# Length: 19612, dtype: int64

# %%
 # Replace NaN and infinite values with 0
X_train = np.nan_to_num(X_train)
X_test = np.nan_to_num(X_test)

# %%
X_train_scaled = X_train
X_test_scaled = X_test

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.partial_fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5
nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
    )

# Second hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 156904
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 156955 (613.11 KB)
# Trainable params: 156955 (613.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5361 - accuracy: 0.7329
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.2918 - accuracy: 0.8738
# Epoch 3/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1539 - accuracy: 0.9411
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1180 - accuracy: 0.9513
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.1063 - accuracy: 0.9543
# Epoch 6/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.1023 - accuracy: 0.9584
# Epoch 7/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0993 - accuracy: 0.9588
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0975 - accuracy: 0.9600
# Epoch 9/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0968 - accuracy: 0.9605
# Epoch 10/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0953 - accuracy: 0.9616
# Epoch 11/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0938 - accuracy: 0.9615
# Epoch 12/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0931 - accuracy: 0.9619
# Epoch 13/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0931 - accuracy: 0.9619
# Epoch 14/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0927 - accuracy: 0.9618
# Epoch 15/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0919 - accuracy: 0.9619
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0918 - accuracy: 0.9623
# Epoch 17/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0913 - accuracy: 0.9620
# Epoch 18/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0908 - accuracy: 0.9620
# Epoch 19/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0906 - accuracy: 0.9628
# Epoch 20/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.0901 - accuracy: 0.9631
# Epoch 21/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.0898 - accuracy: 0.9632
# Epoch 22/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.0895 - accuracy: 0.9631
# Epoch 23/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0894 - accuracy: 0.9626
# Epoch 24/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.0890 - accuracy: 0.9634
# Epoch 25/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.